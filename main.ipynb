# %%
# Importação padrão para utilizar o Selenium
import funcoes
import threading


filtro = [
    "form-filtroAcss-dlgFilterPrefs-tableUser-0-j_idt349",
    "form-filtroAcss-dlgFilterPrefs-tableUser-1-j_idt349",
    "form-filtroAcss-dlgFilterPrefs-tableUser-7-j_idt349",
    "form-filtroAcss-dlgFilterPrefs-tableUser-8-j_idt349",
    "form-filtroAcss-dlgFilterPrefs-tableUser-9-j_idt349",
    ]
data = funcoes.gerar_datas()

x = [
    threading.Thread(target=funcoes.definitiva, args=[filtro[0], data]),
    threading.Thread(target=funcoes.definitiva, args=[filtro[1], data]),
    threading.Thread(target=funcoes.definitiva, args=[filtro[2], data]),
    threading.Thread(target=funcoes.definitiva, args=[filtro[3], data]),
    threading.Thread(target=funcoes.definitiva, args=[filtro[4], data])
     ]
i = 0

x[0].start()

x[1].start()

x[2].start()

x[3].start()

x[4].start()
# Out:
# Por favor digite o mes/ano desejado(mm/aaaa)07/2022
# [WDM] - ====== WebDriver manager ======
# [WDM] - ====== WebDriver manager ======
# [WDM] - ====== WebDriver manager ======
# [WDM] - ====== WebDriver manager ======
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [C:\Users\gleisson.santos\.wdm\drivers\chromedriver\win32\103.0.5060.134\chromedriver.exe] found in cache
# [WDM] - Driver [C:\Users\gleisson.santos\.wdm\drivers\chromedriver\win32\103.0.5060.134\chromedriver.exe] found in cache
# [WDM] - Driver [C:\Users\gleisson.santos\.wdm\drivers\chromedriver\win32\103.0.5060.134\chromedriver.exe] found in cache
# [WDM] - Driver [C:\Users\gleisson.santos\.wdm\drivers\chromedriver\win32\103.0.5060.134\chromedriver.exe] found in cache
# [WDM] - Driver [C:\Users\gleisson.santos\.wdm\drivers\chromedriver\win32\103.0.5060.134\chromedriver.exe] found in cache
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "C:\Users\gleisson.santos\Anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\gleisson.santos\Anaconda3\lib\threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\gleisson.santos\Desktop\Extração de Planilha\funcoes.py", line 118, in definitiva
#     funcoes.trocar_localidade("700", "0", driver)
#   File "C:\Users\gleisson.santos\Desktop\Extração de Planilha\funcoes.py", line 52, in trocar_localidade
#     driver.find_element(by=By.ID, value="form-filtroAcss-solicitacaoBairroId-j_idt205-bairro-input").click()
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 81, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 740, in _execute
#     return self._parent.execute(command, params)
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.ElementClickInterceptedException: Message: element click intercepted: Element <input id="form-filtroAcss-solicitacaoBairroId-j_idt205-bairro-input" type="text" name="form-filtroAcss-solicitacaoBairroId-j_idt205-bairro-input" value="0" style="width: 50px" onchange="mojarra.ab(this,event,'change',0,'form-filtroAcss-solicitacaoEnderecoLogradouroId')" donotfirechangeevent="false"> is not clickable at point (35, 377). Other element would receive the click: <div id="j_idt24_modal" class="ui-widget-overlay" style="width: 825px; height: 606px; z-index: 1007;"></div>
#   (Session info: chrome=103.0.5060.134)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00AE5FD3+2187219]
# 	Ordinal0 [0x00A7E6D1+1763025]
# 	Ordinal0 [0x00993E78+802424]
# 	Ordinal0 [0x009C834B+1016651]
# 	Ordinal0 [0x009C6318+1008408]
# 	Ordinal0 [0x009C401B+999451]
# 	Ordinal0 [0x009C2D69+994665]
# 	Ordinal0 [0x009B89B3+952755]
# 	Ordinal0 [0x009DCB8C+1100684]
# 	Ordinal0 [0x009B8394+951188]
# 	Ordinal0 [0x009DCDA4+1101220]
# 	Ordinal0 [0x009ECFC2+1167298]
# 	Ordinal0 [0x009DC9A6+1100198]
# 	Ordinal0 [0x009B6F80+946048]
# 	Ordinal0 [0x009B7E76+949878]
# 	GetHandleVerifier [0x00D890C2+2721218]
# 	GetHandleVerifier [0x00D7AAF0+2662384]
# 	GetHandleVerifier [0x00B7137A+526458]
# 	GetHandleVerifier [0x00B70416+522518]
# 	Ordinal0 [0x00A84EAB+1789611]
# 	Ordinal0 [0x00A897A8+1808296]
# 	Ordinal0 [0x00A89895+1808533]
# 	Ordinal0 [0x00A926C1+1844929]
# 	BaseThreadInitThunk [0x761CFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x772D7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x772D7A6E+238]
#
# Exception in thread Thread-13:
# Traceback (most recent call last):
#   File "C:\Users\gleisson.santos\Anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\gleisson.santos\Anaconda3\lib\threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\gleisson.santos\Desktop\Extração de Planilha\funcoes.py", line 119, in definitiva
#     funcoes.pesq_exp(driver)
#   File "C:\Users\gleisson.santos\Desktop\Extração de Planilha\funcoes.py", line 61, in pesq_exp
#     driver.find_element(by=By.ID, value="form-filtroAcss-toolbox-btn-search").click()
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 81, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 740, in _execute
#     return self._parent.execute(command, params)
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.ElementClickInterceptedException: Message: element click intercepted: Element <input id="form-filtroAcss-toolbox-btn-search" type="submit" name="form-filtroAcss-toolbox-btn-search" value="Pesquisar"> is not clickable at point (42, 409). Other element would receive the click: <div id="j_idt24_modal" class="ui-widget-overlay" style="width: 825px; height: 606px; z-index: 1008;"></div>
#   (Session info: chrome=103.0.5060.134)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00AE5FD3+2187219]
# 	Ordinal0 [0x00A7E6D1+1763025]
# 	Ordinal0 [0x00993E78+802424]
# 	Ordinal0 [0x009C834B+1016651]
# 	Ordinal0 [0x009C6318+1008408]
# 	Ordinal0 [0x009C401B+999451]
# 	Ordinal0 [0x009C2D69+994665]
# 	Ordinal0 [0x009B89B3+952755]
# 	Ordinal0 [0x009DCB8C+1100684]
# 	Ordinal0 [0x009B8394+951188]
# 	Ordinal0 [0x009DCDA4+1101220]
# 	Ordinal0 [0x009ECFC2+1167298]
# 	Ordinal0 [0x009DC9A6+1100198]
# 	Ordinal0 [0x009B6F80+946048]
# 	Ordinal0 [0x009B7E76+949878]
# 	GetHandleVerifier [0x00D890C2+2721218]
# 	GetHandleVerifier [0x00D7AAF0+2662384]
# 	GetHandleVerifier [0x00B7137A+526458]
# 	GetHandleVerifier [0x00B70416+522518]
# 	Ordinal0 [0x00A84EAB+1789611]
# 	Ordinal0 [0x00A897A8+1808296]
# 	Ordinal0 [0x00A89895+1808533]
# 	Ordinal0 [0x00A926C1+1844929]
# 	BaseThreadInitThunk [0x761CFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x772D7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x772D7A6E+238]
#
# Exception in thread Thread-17:
# Traceback (most recent call last):
#   File "C:\Users\gleisson.santos\Anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\gleisson.santos\Anaconda3\lib\threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\gleisson.santos\Desktop\Extração de Planilha\funcoes.py", line 119, in definitiva
#     funcoes.pesq_exp(driver)
#   File "C:\Users\gleisson.santos\Desktop\Extração de Planilha\funcoes.py", line 61, in pesq_exp
#     driver.find_element(by=By.ID, value="form-filtroAcss-toolbox-btn-search").click()
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 81, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 740, in _execute
#     return self._parent.execute(command, params)
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.ElementClickInterceptedException: Message: element click intercepted: Element <input id="form-filtroAcss-toolbox-btn-search" type="submit" name="form-filtroAcss-toolbox-btn-search" value="Pesquisar"> is not clickable at point (42, 450). Other element would receive the click: <div id="j_idt24_modal" class="ui-widget-overlay" style="width: 825px; height: 647px; z-index: 1008;"></div>
#   (Session info: chrome=103.0.5060.134)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00AE5FD3+2187219]
# 	Ordinal0 [0x00A7E6D1+1763025]
# 	Ordinal0 [0x00993E78+802424]
# 	Ordinal0 [0x009C834B+1016651]
# 	Ordinal0 [0x009C6318+1008408]
# 	Ordinal0 [0x009C401B+999451]
# 	Ordinal0 [0x009C2D69+994665]
# 	Ordinal0 [0x009B89B3+952755]
# 	Ordinal0 [0x009DCB8C+1100684]
# 	Ordinal0 [0x009B8394+951188]
# 	Ordinal0 [0x009DCDA4+1101220]
# 	Ordinal0 [0x009ECFC2+1167298]
# 	Ordinal0 [0x009DC9A6+1100198]
# 	Ordinal0 [0x009B6F80+946048]
# 	Ordinal0 [0x009B7E76+949878]
# 	GetHandleVerifier [0x00D890C2+2721218]
# 	GetHandleVerifier [0x00D7AAF0+2662384]
# 	GetHandleVerifier [0x00B7137A+526458]
# 	GetHandleVerifier [0x00B70416+522518]
# 	Ordinal0 [0x00A84EAB+1789611]
# 	Ordinal0 [0x00A897A8+1808296]
# 	Ordinal0 [0x00A89895+1808533]
# 	Ordinal0 [0x00A926C1+1844929]
# 	BaseThreadInitThunk [0x761CFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x772D7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x772D7A6E+238]
# Exception in thread Thread-16:
# Traceback (most recent call last):
#   File "C:\Users\gleisson.santos\Anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\gleisson.santos\Anaconda3\lib\threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\gleisson.santos\Desktop\Extração de Planilha\funcoes.py", line 118, in definitiva
#     funcoes.trocar_localidade("700", "0", driver)
#   File "C:\Users\gleisson.santos\Desktop\Extração de Planilha\funcoes.py", line 52, in trocar_localidade
#     driver.find_element(by=By.ID, value="form-filtroAcss-solicitacaoBairroId-j_idt205-bairro-input").click()
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 81, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 740, in _execute
#     return self._parent.execute(command, params)
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\gleisson.santos\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.ElementClickInterceptedException: Message: element click intercepted: Element <input id="form-filtroAcss-solicitacaoBairroId-j_idt205-bairro-input" type="text" name="form-filtroAcss-solicitacaoBairroId-j_idt205-bairro-input" value="0" style="width: 50px" onchange="mojarra.ab(this,event,'change',0,'form-filtroAcss-solicitacaoEnderecoLogradouroId')" donotfirechangeevent="false"> is not clickable at point (398, 334). Other element would receive the click: <div id="j_idt24_modal" class="ui-widget-overlay" style="width: 825px; height: 649px; z-index: 1006;"></div>
#   (Session info: chrome=103.0.5060.134)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00AE5FD3+2187219]
# 	Ordinal0 [0x00A7E6D1+1763025]
# 	Ordinal0 [0x00993E78+802424]
# 	Ordinal0 [0x009C834B+1016651]
# 	Ordinal0 [0x009C6318+1008408]
# 	Ordinal0 [0x009C401B+999451]
# 	Ordinal0 [0x009C2D69+994665]
# 	Ordinal0 [0x009B89B3+952755]
# 	Ordinal0 [0x009DCB8C+1100684]
# 	Ordinal0 [0x009B8394+951188]
# 	Ordinal0 [0x009DCDA4+1101220]
# 	Ordinal0 [0x009ECFC2+1167298]
# 	Ordinal0 [0x009DC9A6+1100198]
# 	Ordinal0 [0x009B6F80+946048]
# 	Ordinal0 [0x009B7E76+949878]
# 	GetHandleVerifier [0x00D890C2+2721218]
# 	GetHandleVerifier [0x00D7AAF0+2662384]
# 	GetHandleVerifier [0x00B7137A+526458]
# 	GetHandleVerifier [0x00B70416+522518]
# 	Ordinal0 [0x00A84EAB+1789611]
# 	Ordinal0 [0x00A897A8+1808296]
# 	Ordinal0 [0x00A89895+1808533]
# 	Ordinal0 [0x00A926C1+1844929]
# 	BaseThreadInitThunk [0x761CFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x772D7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x772D7A6E+238]
